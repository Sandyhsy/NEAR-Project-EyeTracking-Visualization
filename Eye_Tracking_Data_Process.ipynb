# %% [markdown]
# # NEAR Project Visualization

# %% [markdown]
# Visualize , gaze point, fixation, and blink

# %% [markdown]
# Mount file to colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Heatmap and Gaze point

# %%
import imageio.v2 as imageio
from collections import Counter
from PIL import Image
import numpy as np
import os, glob, shutil, re
from collections import defaultdict
from pathlib import Path

# ---- task folders & Drive output root ----
# Corrected SRC_ROOT to point to the shared drive shortcut
SRC_ROOT = (
    "/content/drive/.shortcut-targets-by-id/"
    "1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL"
    "/NEAR_Experiment_Design/PilotData_V1_10232025"
)
DRIVE_ROOT = "/content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint"

# Subject -> list of task folder names under SRC_ROOT
WINDOW_SEC = 3.0
TASKS = {
    "AT":  ["AT_1", "AT_2", "AT_3_1", "AT_3_2"],
    "Ayu": ["Ayu_1", "Ayu_2", "Ayu_3"],
    "JC":  ["JC_1", "JC_2", "JC_3_1", "JC_3_2"],
    "KC":  ["KC_1", "KC_2", "KC_3_1", "KC_3_2"],
    "LKH": ["LKH_1", "LKH_2", "LKH_3_1", "LKH_3_2"],
    "SYH": ["SYH_1_simple", "SYH_2_simple", "SYH_3_1_simple", "SYH_3_2_simple"],
    "YL":  ["YL_1", "YL_2", "YL_3"],
}

# ---- utilities ----
def sort_by_window(files):
    """Sort filenames like AT_000-005s_heat.png by window start (000)."""
    def key_fn(p):
        m = re.search(r"_(\d+)-\d+s", os.path.basename(p))
        return int(m.group(1)) if m else 10**9
    return sorted(files, key=key_fn)

def to_even_size(size):
    """Make (W,H) even to avoid H.264 issues."""
    w, h = size
    w = w - (w % 2)
    h = h - (h % 2)
    # guard minimums
    w = max(2, w); h = max(2, h)
    return (w, h)

def ensure_dirs(subject):
    """Create subject-specific output folders on Drive."""
    os.makedirs(f"{DRIVE_ROOT}/heatmap/{subject}", exist_ok=True)
    os.makedirs(f"{DRIVE_ROOT}/gaze_point/{subject}", exist_ok=True)
    os.makedirs(f"{DRIVE_ROOT}/animation/{subject}", exist_ok=True)

def clear_local_output():
    """Clear local output folders before each task to avoid mixing frames."""
    for p in ["/content/heat_map", "/content/gaze_point"]:
        if os.path.exists(p):
            for f in glob.glob(os.path.join(p, "*")):
                try:
                    os.remove(f)
                except IsADirectoryError:
                    shutil.rmtree(f, ignore_errors=True)
        else:
            os.makedirs(p, exist_ok=True)

def copy_with_prefix(src_glob, dst_dir, prefix):
    """Copy files matching src_glob into dst_dir; prefix the filename with `prefix` to avoid collisions."""
    files = sorted(glob.glob(src_glob))
    if not files:
        print(f"[copy] No match: {src_glob}")
        return 0
    count = 0
    for s in files:
        base = os.path.basename(s)
        base_tail = base.split("_", 1)[1] if "_" in base else base
        new_name = f"{prefix}_{base_tail}"
        dst = os.path.join(dst_dir, new_name)
        shutil.copy2(s, dst)
        count += 1
    print(f"[copy] {count} files -> {dst_dir} (prefix={prefix})")
    return count

def make_mp4_from_folder(folder, pattern, out_mp4_path, fps=2):
    """
    Create an MP4 video from PNGs in `folder` matching `pattern`.
    Frames are converted to RGB and resized to a common even size.
    fps controls playback speed (lower = slower).
    """
    files = sort_by_window(glob.glob(os.path.join(folder, pattern)))
    print(f"[video] Found {len(files)} frames for {out_mp4_path}")
    if not files:
        print("[video] No frames, skipped:", out_mp4_path)
        return

    # decide target size using the most common WxH, then make it even
    sizes = []
    for p in files:
        with Image.open(p) as im:
            sizes.append(im.size)
    common_size = Counter(sizes).most_common(1)[0][0]
    target_size = to_even_size(common_size)
    print("[video] Target frame size:", target_size, "(from most common size:", common_size, ")")
    print("[video] FPS:", fps)

    # write mp4 using imageio-ffmpeg (libx264)
    # Note: quality=8 is a good balance; you can tweak if needed.
    with imageio.get_writer(out_mp4_path, fps=fps, codec="libx264", quality=8, macro_block_size=None) as writer:
        for p in files:
            im = Image.open(p).convert("RGB")
            if im.size != target_size:
                print(f"  [resize] {os.path.basename(p)} {im.size} -> {target_size}")
                im = im.resize(target_size, Image.LANCZOS)
            frame = np.array(im)  # RGB
            writer.append_data(frame)

    print("[video] Saved:", out_mp4_path)

# ---- per-task runner ----
def run_one_task(task_dir, subject, task_tag, window_sec=WINDOW_SEC):
    """
    Run your existing visualization pipeline for one task_dir.
    Assumes the earlier cell's functions are already defined in this runtime:
      - load_gaze_dataframe, open_world_video, plot_and_save_heatmap, plot_and_save_points
    Saves PNGs to /content/heat_map and /content/gaze_point, and MP4 to those folders as well.
    Then copies them to Drive, renaming with 'task_tag__' prefix to avoid collisions.
    """
    print("\n" + "="*80)
    print(f"[run] Subject={subject} | Task={task_tag} | Dir={task_dir}")
    print("="*80)

    # clean local outputs so frames belong only to this task
    clear_local_output()

    # ---- generate frames + mp4 using your existing functions ----
    # If you encapsulated your earlier logic as a function, just call it here (preferred).
    # Otherwise, reproduce the essential calls inline:

    # 1) Load gaze
    gaze_df = load_gaze_dataframe(task_dir)
    print("[gaze_df] shape:", gaze_df.shape)

    # 2) Open video
    cap, fps, frame_count, duration, W, H = open_world_video(task_dir)

    # 3) Windowing and per-window plots (same as your earlier cell)
    WINDOW_SEC = float(window_sec)
    t_min = float(gaze_df["timestamp"].min())
    gaze_df = gaze_df.assign(t_rel=gaze_df["timestamp"] - t_min)
    t_max_rel = float(gaze_df["t_rel"].max())
    max_duration = min(duration, t_max_rel)
    num_windows = int(max_duration // WINDOW_SEC) + 1
    print(f"[time] 0..{max_duration:.2f}s | window={WINDOW_SEC}s | windows≈{num_windows}")

    for k in range(num_windows):
        start_t = k * WINDOW_SEC
        end_t = min((k + 1) * WINDOW_SEC, max_duration)
        if end_t <= start_t + 1e-6:
            continue
        win_mask = (gaze_df["t_rel"] >= start_t) & (gaze_df["t_rel"] < end_t)
        df_win = gaze_df.loc[win_mask]
        if df_win.empty:
            continue

        # mid frame
        mid_t = 0.5 * (start_t + end_t)
        frame_bgr = grab_frame_at_time(cap, fps, mid_t)
        if frame_bgr is None:
            continue
        import cv2
        frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)

        # filenames (keep your original SUBJECT-only names here)
        tag = f"{int(start_t):03d}-{int(end_t):03d}s"
        heat_path = f"/content/heat_map/{subject}_{tag}_heat.png"
        pts_path  = f"/content/gaze_point/{subject}_{tag}_points.png"

        plot_and_save_heatmap(frame_rgb, df_win, heat_path)
        plot_and_save_points(frame_rgb, df_win, pts_path)

    cap.release()

    # 4) Build MP4s from the frames
    make_mp4_from_folder("/content/heat_map",  f"{subject}_*-*s_heat.png",
                         f"/content/heat_map/{subject}_heatmap.mp4", fps=2)
    make_mp4_from_folder("/content/gaze_point", f"{subject}_*-*s_points.png",
                         f"/content/gaze_point/{subject}_gaze_points.mp4", fps=2)


    # ---- copy to Drive, prefixing with task tag to avoid collisions ----
    ensure_dirs(subject)
    copy_with_prefix("/content/heat_map/*.png",   f"{DRIVE_ROOT}/heatmap/{subject}",   prefix=task_tag)
    copy_with_prefix("/content/gaze_point/*.png", f"{DRIVE_ROOT}/gaze_point/{subject}",prefix=task_tag)

    # MP4s → animation
    mp4_count  = copy_with_prefix("/content/heat_map/*.mp4",   f"{DRIVE_ROOT}/animation/{subject}", prefix=task_tag)
    mp4_count += copy_with_prefix("/content/gaze_point/*.mp4", f"{DRIVE_ROOT}/animation/{subject}", prefix=task_tag)
    if mp4_count == 0:
        print("[note] No MP4s for this task (ok).")

# ---- Run ----
for subject, task_list in TASKS.items():
    for task_tag in task_list:
        task_dir = os.path.join(SRC_ROOT, task_tag)
        if not os.path.isdir(task_dir):
            print(f"[skip] Task dir not found: {task_dir}")
            continue
        try:
            run_one_task(task_dir, subject=subject, task_tag=task_tag, window_sec=WINDOW_SEC)
        except Exception as e:
            print(f"[ERROR] {subject}:{task_tag} -> {e}")
# Out:
# ================================================================================
# [run] Subject=AT | Task=AT_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66047.764624    0.484016    0.000000         0.0
# 1  66047.768253    0.059118    0.904931         0.0
# 2  66047.772357    0.484016    0.000000         0.0
# 3  66047.776310    0.059118    0.904931         0.0
# 4  66047.783914    0.484016    0.000000         0.0
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66047.764624    0.484016    0.000000         0.0
# 1  66047.768253    0.059118    0.904931         0.0
# 2  66047.772357    0.484016    0.000000         0.0
# 3  66047.776310    0.059118    0.904931         0.0
# 4  66047.783914    0.484016    0.000000         0.0
# [gaze_df] shape: (16220, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_1/world.mp4
# [video] fps=29.827, frames=2078, size=(1280x720), duration=69.67s
# [time] 0..69.66s | window=3.0s | windows≈24
# [video] Found 24 frames for /content/heat_map/AT_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/AT_heatmap.mp4
# [video] Found 24 frames for /content/gaze_point/AT_gaze_points.mp4
# [video] Target frame size: (2000, 1182) (from most common size: (2000, 1182) )
# [video] FPS: 2
#   [resize] AT_000-003s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_003-006s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_012-015s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_015-018s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_030-033s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_036-039s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_039-042s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_060-063s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_063-066s_points.png (2000, 1125) -> (2000, 1182)
# [video] Saved: /content/gaze_point/AT_gaze_points.mp4
# [copy] 24 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/AT (prefix=AT_1)
# [copy] 24 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/AT (prefix=AT_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_1)
#
# ================================================================================
# [run] Subject=AT | Task=AT_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66147.124498    0.485913     0.00000         0.0
# 1  66147.124499    0.060246     0.90449         0.0
# 2  66147.141429    0.060246     0.90449         0.0
# 3  66147.141691    0.485913     0.00000         0.0
# 4  66147.148412    0.485913     0.00000         0.0
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66147.124498    0.485913     0.00000         0.0
# 1  66147.124499    0.060246     0.90449         0.0
# 2  66147.141429    0.060246     0.90449         0.0
# 3  66147.141691    0.485913     0.00000         0.0
# 4  66147.148412    0.485913     0.00000         0.0
# [gaze_df] shape: (6657, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_2/world.mp4
# [video] fps=29.734, frames=841, size=(1280x720), duration=28.28s
# [time] 0..28.28s | window=3.0s | windows≈10
# [video] Found 10 frames for /content/heat_map/AT_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/AT_heatmap.mp4
# [video] Found 10 frames for /content/gaze_point/AT_gaze_points.mp4
# [video] Target frame size: (2000, 1182) (from most common size: (2000, 1182) )
# [video] FPS: 2
#   [resize] AT_006-009s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_009-012s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_018-021s_points.png (2000, 1125) -> (2000, 1182)
# [video] Saved: /content/gaze_point/AT_gaze_points.mp4
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/AT (prefix=AT_2)
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/AT (prefix=AT_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_2)
#
# ================================================================================
# [run] Subject=AT | Task=AT_3_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66202.051628    0.393781    0.000000    0.000000
# 1  66202.054506    0.000000    0.904433    0.000000
# 2  66202.056300    0.393781    0.000000    0.000000
# 3  66202.062030    0.218950    1.000000    0.715302
# 4  66202.062775    0.393781    0.000000    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66202.051628    0.393781    0.000000    0.000000
# 1  66202.054506    0.000000    0.904433    0.000000
# 2  66202.056300    0.393781    0.000000    0.000000
# 3  66202.062030    0.218950    1.000000    0.715302
# 4  66202.062775    0.393781    0.000000    0.000000
# [gaze_df] shape: (4628, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_1/world.mp4
# [video] fps=29.842, frames=583, size=(1280x720), duration=19.54s
# [time] 0..19.52s | window=3.0s | windows≈7
# [video] Found 7 frames for /content/heat_map/AT_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/AT_heatmap.mp4
# [video] Found 7 frames for /content/gaze_point/AT_gaze_points.mp4
# [video] Target frame size: (2000, 1182) (from most common size: (2000, 1182) )
# [video] FPS: 2
#   [resize] AT_003-006s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] AT_009-012s_points.png (2000, 1125) -> (2000, 1182)
# [video] Saved: /content/gaze_point/AT_gaze_points.mp4
# [copy] 7 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/AT (prefix=AT_3_1)
# [copy] 7 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/AT (prefix=AT_3_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_3_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_3_1)
#
# ================================================================================
# [run] Subject=AT | Task=AT_3_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66260.252512    0.542514    0.000000         0.0
# 1  66260.252512    0.060758    0.904792         0.0
# 2  66260.260362    0.060758    0.904792         0.0
# 3  66260.260362    0.542514    0.000000         0.0
# 4  66260.270226    0.542514    0.000000         0.0
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  66260.252512    0.542514    0.000000         0.0
# 1  66260.252512    0.060758    0.904792         0.0
# 2  66260.260362    0.542514    0.000000         0.0
# 3  66260.260362    0.060758    0.904792         0.0
# 4  66260.270226    0.542514    0.000000         0.0
# [gaze_df] shape: (10704, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/AT_3_2/world.mp4
# [video] fps=29.865, frames=1342, size=(1280x720), duration=44.94s
# [time] 0..44.93s | window=3.0s | windows≈15
# [video] Found 15 frames for /content/heat_map/AT_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/AT_heatmap.mp4
# [video] Found 15 frames for /content/gaze_point/AT_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] AT_000-003s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] AT_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_027-030s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_030-033s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_033-036s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_036-039s_points.png (2000, 1071) -> (2000, 1124)
#   [resize] AT_039-042s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] AT_042-044s_points.png (2000, 1182) -> (2000, 1124)
# [video] Saved: /content/gaze_point/AT_gaze_points.mp4
# [copy] 15 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/AT (prefix=AT_3_2)
# [copy] 15 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/AT (prefix=AT_3_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_3_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/AT (prefix=AT_3_2)
#
# ================================================================================
# [run] Subject=Ayu | Task=Ayu_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63455.465609    0.717625    0.093071    0.301628
# 1  63455.466771    0.000000    1.000000    0.000000
# 2  63455.475075    0.000000    1.000000    0.000000
# 3  63455.477785    0.293077    0.813554    0.778713
# 4  63455.479601    0.719416    0.168021    0.282281
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63455.465609    0.717625    0.093071    0.301628
# 1  63455.466771    0.000000    1.000000    0.000000
# 2  63455.475075    0.000000    1.000000    0.000000
# 3  63455.477785    0.293077    0.813554    0.778713
# 4  63455.479601    0.719416    0.168021    0.282281
# [gaze_df] shape: (13572, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_1/world.mp4
# [video] fps=29.841, frames=1761, size=(1280x720), duration=59.01s
# [time] 0..59.00s | window=3.0s | windows≈20
# [video] Found 20 frames for /content/heat_map/Ayu_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/Ayu_heatmap.mp4
# [video] Found 20 frames for /content/gaze_point/Ayu_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] Ayu_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_012-015s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_015-018s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_018-021s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_021-024s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_027-030s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_030-033s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_033-036s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_036-039s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_039-042s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_042-045s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_045-048s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_048-051s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_051-054s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_054-057s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_057-059s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/Ayu_gaze_points.mp4
# [copy] 20 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/Ayu (prefix=Ayu_1)
# [copy] 20 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/Ayu (prefix=Ayu_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_1)
#
# ================================================================================
# [run] Subject=Ayu | Task=Ayu_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63562.494806    1.000000    1.000000    0.060799
# 1  63562.495963    0.539907    0.175590    0.379212
# 2  63562.502779    1.000000    1.000000    0.067284
# 3  63562.508043    0.542549    0.198992    0.469359
# 4  63562.510884    1.000000    1.000000    0.085708
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63562.494806    1.000000    1.000000    0.060799
# 1  63562.495963    0.539907    0.175590    0.379212
# 2  63562.502779    1.000000    1.000000    0.067284
# 3  63562.508043    0.542549    0.198992    0.469359
# 4  63562.510884    1.000000    1.000000    0.085708
# [gaze_df] shape: (8627, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_2/world.mp4
# [video] fps=29.690, frames=1166, size=(1280x720), duration=39.27s
# [time] 0..39.26s | window=3.0s | windows≈14
# [video] Found 14 frames for /content/heat_map/Ayu_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/Ayu_heatmap.mp4
# [video] Found 14 frames for /content/gaze_point/Ayu_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] Ayu_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_003-006s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_006-009s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_012-015s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_018-021s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_021-024s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_027-030s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_030-033s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] Ayu_033-036s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_036-039s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] Ayu_039-039s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/Ayu_gaze_points.mp4
# [copy] 14 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/Ayu (prefix=Ayu_2)
# [copy] 14 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/Ayu (prefix=Ayu_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_2)
#
# ================================================================================
# [run] Subject=Ayu | Task=Ayu_3 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_3
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_3/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63631.993528    0.202734    0.974935    0.741492
# 1  63632.004756    0.957143    0.469960    0.000000
# 2  63632.009006    0.005211    1.000000    0.000000
# 3  63632.014212    0.957143    0.469960    0.000000
# 4  63632.019417    0.005211    1.000000    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63631.993528    0.202734    0.974935    0.741492
# 1  63632.004756    0.957143    0.469960    0.000000
# 2  63632.009006    0.005211    1.000000    0.000000
# 3  63632.014212    0.957143    0.469960    0.000000
# 4  63632.019417    0.005211    1.000000    0.000000
# [gaze_df] shape: (15937, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/Ayu_3/world.mp4
# [video] fps=29.854, frames=2320, size=(1280x720), duration=77.71s
# [time] 0..77.70s | window=3.0s | windows≈26
# [video] Found 26 frames for /content/heat_map/Ayu_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/Ayu_heatmap.mp4
# [video] Found 26 frames for /content/gaze_point/Ayu_gaze_points.mp4
# [video] Target frame size: (2000, 1182) (from most common size: (2000, 1182) )
# [video] FPS: 2
#   [resize] Ayu_003-006s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] Ayu_030-033s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] Ayu_048-051s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] Ayu_075-077s_points.png (2000, 1125) -> (2000, 1182)
# [video] Saved: /content/gaze_point/Ayu_gaze_points.mp4
# [copy] 26 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/Ayu (prefix=Ayu_3)
# [copy] 26 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/Ayu (prefix=Ayu_3)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_3)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/Ayu (prefix=Ayu_3)
#
# ================================================================================
# [run] Subject=JC | Task=JC_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  64942.727334    0.999379    0.765275    0.000000
# 1  64942.734106    0.157704    0.229502    0.575723
# 2  64942.737981    0.999379    0.765275    0.000000
# 3  64942.753796    0.213052    0.320672    0.565245
# 4  64942.754403    0.999379    0.765275    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  64942.727334    0.999379    0.765275    0.000000
# 1  64942.734106    0.157704    0.229502    0.575723
# 2  64942.737981    0.999379    0.765275    0.000000
# 3  64942.753796    0.213052    0.320672    0.565245
# 4  64942.754403    0.999379    0.765275    0.000000
# [gaze_df] shape: (7617, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_1/world.mp4
# [video] fps=29.699, frames=1641, size=(1280x720), duration=55.25s
# [time] 0..55.24s | window=3.0s | windows≈19
# [video] Found 19 frames for /content/heat_map/JC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/JC_heatmap.mp4
# [video] Found 19 frames for /content/gaze_point/JC_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] JC_000-003s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_027-030s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_030-033s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_033-036s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_036-039s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_039-042s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_042-045s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_045-048s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_048-051s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_051-054s_points.png (2000, 1071) -> (2000, 1124)
#   [resize] JC_054-055s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/JC_gaze_points.mp4
# [copy] 19 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/JC (prefix=JC_1)
# [copy] 19 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/JC (prefix=JC_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_1)
#
# ================================================================================
# [run] Subject=JC | Task=JC_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65049.656724         1.0    0.768478    0.000000
# 1  65049.661128         1.0    0.859134    0.833402
# 2  65049.669135         1.0    0.768478    0.000000
# 3  65049.672689         1.0    0.857391    0.907644
# 4  65049.687315         1.0    0.768478    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65049.656724         1.0    0.768478    0.000000
# 1  65049.661128         1.0    0.859134    0.833402
# 2  65049.669135         1.0    0.768478    0.000000
# 3  65049.672689         1.0    0.857391    0.907644
# 4  65049.687315         1.0    0.768478    0.000000
# [gaze_df] shape: (15937, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_2/world.mp4
# [video] fps=29.670, frames=2763, size=(1280x720), duration=93.12s
# [time] 0..93.12s | window=3.0s | windows≈32
# [video] Found 32 frames for /content/heat_map/JC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/JC_heatmap.mp4
# [video] Found 32 frames for /content/gaze_point/JC_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] JC_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_003-006s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_027-030s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_030-033s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_033-036s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_036-039s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_039-042s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_042-045s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_045-048s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_048-051s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_051-054s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_054-057s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_057-060s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_060-063s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_063-066s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_066-069s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_069-072s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_072-075s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_075-078s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_078-081s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_081-084s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_084-087s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_087-090s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_090-093s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_093-093s_points.png (2000, 1182) -> (2000, 1124)
# [video] Saved: /content/gaze_point/JC_gaze_points.mp4
# [copy] 32 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/JC (prefix=JC_2)
# [copy] 32 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/JC (prefix=JC_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_2)
#
# ================================================================================
# [run] Subject=JC | Task=JC_3_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65175.857649    0.997413    0.771156    0.000000
# 1  65175.860583    0.939471    1.000000    0.369926
# 2  65175.870396    0.997413    0.771156    0.000000
# 3  65175.874506    1.000000    1.000000    0.410354
# 4  65175.888354    1.000000    1.000000    0.383500
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65175.857649    0.997413    0.771156    0.000000
# 1  65175.860583    0.939471    1.000000    0.369926
# 2  65175.870396    0.997413    0.771156    0.000000
# 3  65175.874506    1.000000    1.000000    0.410354
# 4  65175.888354    1.000000    1.000000    0.383500
# [gaze_df] shape: (4119, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_1/world.mp4
# [video] fps=29.462, frames=851, size=(1280x720), duration=28.88s
# [time] 0..28.87s | window=3.0s | windows≈10
# [video] Found 10 frames for /content/heat_map/JC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/JC_heatmap.mp4
# [video] Found 10 frames for /content/gaze_point/JC_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] JC_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_003-006s_points.png (2000, 1071) -> (2000, 1124)
#   [resize] JC_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_009-012s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_012-015s_points.png (2000, 1071) -> (2000, 1124)
#   [resize] JC_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_018-021s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_021-024s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] JC_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_027-028s_points.png (2000, 1182) -> (2000, 1124)
# [video] Saved: /content/gaze_point/JC_gaze_points.mp4
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/JC (prefix=JC_3_1)
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/JC (prefix=JC_3_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_3_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_3_1)
#
# ================================================================================
# [run] Subject=JC | Task=JC_3_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65230.353578    0.994315    0.775104    0.000000
# 1  65230.354371    0.000000    0.000000    0.582724
# 2  65230.363600    0.994315    0.775104    0.000000
# 3  65230.371741    1.000000    1.000000    0.537442
# 4  65230.377346    0.994315    0.775104    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65230.353578    0.994315    0.775104    0.000000
# 1  65230.354371    0.000000    0.000000    0.582724
# 2  65230.363600    0.994315    0.775104    0.000000
# 3  65230.371741    1.000000    1.000000    0.537442
# 4  65230.377346    0.994315    0.775104    0.000000
# [gaze_df] shape: (5634, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/JC_3_2/world.mp4
# [video] fps=29.605, frames=1233, size=(1280x720), duration=41.65s
# [time] 0..41.63s | window=3.0s | windows≈14
# [video] Found 14 frames for /content/heat_map/JC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/JC_heatmap.mp4
# [video] Found 14 frames for /content/gaze_point/JC_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] JC_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_027-030s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_030-033s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_033-036s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_036-039s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] JC_039-041s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/JC_gaze_points.mp4
# [copy] 14 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/JC (prefix=JC_3_2)
# [copy] 14 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/JC (prefix=JC_3_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_3_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/JC (prefix=JC_3_2)
#
# ================================================================================
# [run] Subject=KC | Task=KC_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65452.214967    0.461041    0.690496    0.473531
# 1  65452.215489    0.574475    0.645679    0.529487
# 2  65452.236782    0.461513    0.690953    0.546553
# 3  65452.237960    0.584243    0.641206    0.600000
# 4  65452.274697    0.460712    0.688813    0.432097
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65452.214967    0.461041    0.690496    0.473531
# 1  65452.215489    0.574475    0.645679    0.529487
# 2  65452.236782    0.461513    0.690953    0.546553
# 3  65452.237960    0.584243    0.641206    0.600000
# 4  65452.274697    0.460712    0.688813    0.432097
# [gaze_df] shape: (3134, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_1/world.mp4
# [video] fps=28.929, frames=823, size=(1280x720), duration=28.45s
# [time] 0..28.44s | window=3.0s | windows≈10
# [video] Found 10 frames for /content/heat_map/KC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/KC_heatmap.mp4
# [video] Found 10 frames for /content/gaze_point/KC_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] KC_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_024-027s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] KC_027-028s_points.png (2000, 1182) -> (2000, 1124)
# [video] Saved: /content/gaze_point/KC_gaze_points.mp4
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/KC (prefix=KC_1)
# [copy] 10 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/KC (prefix=KC_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/KC (prefix=KC_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/KC (prefix=KC_1)
#
# ================================================================================
# [run] Subject=KC | Task=KC_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65537.330669    0.500572    0.763235    0.508531
# 1  65537.334259    0.251962    0.380030    0.000000
# 2  65537.350505    0.251962    0.380030    0.000000
# 3  65537.351697    0.494496    0.752014    0.737891
# 4  65537.360373    0.251962    0.380030    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  65537.330669    0.500572    0.763235    0.508531
# 1  65537.334259    0.251962    0.380030    0.000000
# 2  65537.350505    0.251962    0.380030    0.000000
# 3  65537.351697    0.494496    0.752014    0.737891
# 4  65537.360373    0.251962    0.380030    0.000000
# [gaze_df] shape: (6646, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/KC_2/world.mp4
# [video] fps=29.620, frames=1343, size=(1280x720), duration=45.34s
# [time] 0..45.33s | window=3.0s | windows≈16
# [video] Found 16 frames for /content/heat_map/KC_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/KC_heatmap.mp4
# ...
# 3  64192.407432    0.781685    0.647704    0.172905
# 4  64192.409393    0.146101    1.000000    0.925497
# [gaze_df] shape: (4678, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/SYH_3_1_simple/world.mp4
# [video] fps=29.525, frames=646, size=(1280x720), duration=21.88s
# [time] 0..21.86s | window=3.0s | windows≈8
# [video] Found 8 frames for /content/heat_map/SYH_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/SYH_heatmap.mp4
# [video] Found 8 frames for /content/gaze_point/SYH_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] SYH_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_021-021s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/SYH_gaze_points.mp4
# [copy] 8 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/SYH (prefix=SYH_3_1_simple)
# [copy] 8 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/SYH (prefix=SYH_3_1_simple)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/SYH (prefix=SYH_3_1_simple)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/SYH (prefix=SYH_3_1_simple)
#
# ================================================================================
# [run] Subject=SYH | Task=SYH_3_2_simple | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/SYH_3_2_simple
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/SYH_3_2_simple/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  64234.377356    0.218231         1.0         0.6
# 1  64234.381841    0.217801         1.0         0.6
# 2  64234.385804    0.211970         1.0         0.6
# 3  64234.389473    0.212459         1.0         0.6
# 4  64234.393493    0.214715         1.0         0.6
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  64234.377356    0.218231         1.0         0.6
# 1  64234.381841    0.217801         1.0         0.6
# 2  64234.385804    0.211970         1.0         0.6
# 3  64234.389473    0.212459         1.0         0.6
# 4  64234.393493    0.214715         1.0         0.6
# [gaze_df] shape: (5093, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/SYH_3_2_simple/world.mp4
# [video] fps=29.194, frames=630, size=(1280x720), duration=21.58s
# [time] 0..21.58s | window=3.0s | windows≈8
# [video] Found 7 frames for /content/heat_map/SYH_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/SYH_heatmap.mp4
# [video] Found 7 frames for /content/gaze_point/SYH_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] SYH_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] SYH_018-021s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/SYH_gaze_points.mp4
# [copy] 7 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/SYH (prefix=SYH_3_2_simple)
# [copy] 7 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/SYH (prefix=SYH_3_2_simple)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/SYH (prefix=SYH_3_2_simple)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/SYH (prefix=SYH_3_2_simple)
#
# ================================================================================
# [run] Subject=YL | Task=YL_1 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_1
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_1/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  62877.965487    1.000000    1.000000    0.000000
# 1  62877.969287    0.587359    0.000000    0.000000
# 2  62877.972507    0.315593    0.076987    0.799561
# 3  62877.976311    0.587359    0.000000    0.000000
# 4  62877.980862    1.000000    1.000000    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  62877.965487    1.000000    1.000000    0.000000
# 1  62877.969287    0.587359    0.000000    0.000000
# 2  62877.972507    0.315593    0.076987    0.799561
# 3  62877.976311    0.587359    0.000000    0.000000
# 4  62877.980862    1.000000    1.000000    0.000000
# [gaze_df] shape: (9312, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_1/world.mp4
# [video] fps=29.780, frames=1285, size=(1280x720), duration=43.15s
# [time] 0..43.15s | window=3.0s | windows≈15
# [video] Found 15 frames for /content/heat_map/YL_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/YL_heatmap.mp4
# [video] Found 15 frames for /content/gaze_point/YL_gaze_points.mp4
# [video] Target frame size: (2000, 1182) (from most common size: (2000, 1182) )
# [video] FPS: 2
#   [resize] YL_000-003s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_003-006s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_015-018s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_018-021s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_021-024s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_027-030s_points.png (2000, 1125) -> (2000, 1182)
#   [resize] YL_033-036s_points.png (2000, 1125) -> (2000, 1182)
# [video] Saved: /content/gaze_point/YL_gaze_points.mp4
# [copy] 15 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/YL (prefix=YL_1)
# [copy] 15 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/YL (prefix=YL_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_1)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_1)
#
# ================================================================================
# [run] Subject=YL | Task=YL_2 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_2
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_2/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  62961.382241    0.342210    0.000000    0.438659
# 1  62961.382247    0.683889    0.312260    0.600000
# 2  62961.390142    0.355643    0.000000    0.452545
# 3  62961.390531    0.687666    0.314122    0.600000
# 4  62961.398273    0.354849    0.000000    0.508464
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  62961.382241    0.342210    0.000000    0.438659
# 1  62961.382247    0.683889    0.312260    0.600000
# 2  62961.390142    0.355643    0.000000    0.452545
# 3  62961.390531    0.687666    0.314122    0.600000
# 4  62961.398273    0.354849    0.000000    0.508464
# [gaze_df] shape: (6534, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_2/world.mp4
# [video] fps=29.243, frames=798, size=(1280x720), duration=27.29s
# [time] 0..27.28s | window=3.0s | windows≈10
# [video] Found 9 frames for /content/heat_map/YL_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/YL_heatmap.mp4
# [video] Found 9 frames for /content/gaze_point/YL_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] YL_000-003s_points.png (2000, 1182) -> (2000, 1124)
#   [resize] YL_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_021-024s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_024-027s_points.png (2000, 1125) -> (2000, 1124)
# [video] Saved: /content/gaze_point/YL_gaze_points.mp4
# [copy] 9 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/YL (prefix=YL_2)
# [copy] 9 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/YL (prefix=YL_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_2)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_2)
#
# ================================================================================
# [run] Subject=YL | Task=YL_3 | Dir=/content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_3
# ================================================================================
# [exports] Loading: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_3/exports/000/gaze_positions.csv
# [exports] Columns: ['gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
# [exports] norm_pos outside [0,1]; applying auto-normalization
# [exports] Using timestamp: gaze_timestamp | positions from normalized columns: norm_pos_x,norm_pos_y
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63025.715688    0.270688         0.0    0.352560
# 1  63025.718776    0.597032         0.0    0.000000
# 2  63025.726106    0.261345         0.0    0.448806
# 3  63025.726682    0.597032         0.0    0.000000
# 4  63025.734654    0.597032         0.0    0.000000
# [info] Using gaze from exports CSVs
#       timestamp  norm_pos_x  norm_pos_y  confidence
# 0  63025.715688    0.270688         0.0    0.352560
# 1  63025.718776    0.597032         0.0    0.000000
# 2  63025.726106    0.261345         0.0    0.448806
# 3  63025.726682    0.597032         0.0    0.000000
# 4  63025.734654    0.597032         0.0    0.000000
# [gaze_df] shape: (5133, 4)
# Opening video: /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025/YL_3/world.mp4
# [video] fps=29.693, frames=692, size=(1280x720), duration=23.31s
# [time] 0..23.30s | window=3.0s | windows≈8
# [video] Found 8 frames for /content/heat_map/YL_heatmap.mp4
# [video] Target frame size: (2000, 1200) (from most common size: (2000, 1200) )
# [video] FPS: 2
# [video] Saved: /content/heat_map/YL_heatmap.mp4
# [video] Found 8 frames for /content/gaze_point/YL_gaze_points.mp4
# [video] Target frame size: (2000, 1124) (from most common size: (2000, 1125) )
# [video] FPS: 2
#   [resize] YL_000-003s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_003-006s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_006-009s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_009-012s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_012-015s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_015-018s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_018-021s_points.png (2000, 1125) -> (2000, 1124)
#   [resize] YL_021-023s_points.png (2000, 1182) -> (2000, 1124)
# [video] Saved: /content/gaze_point/YL_gaze_points.mp4
# [copy] 8 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/heatmap/YL (prefix=YL_3)
# [copy] 8 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/gaze_point/YL (prefix=YL_3)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_3)
# [copy] 1 files -> /content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/heatmap_gazepoint/animation/YL (prefix=YL_3)

# %% [markdown]
# ## Fixation Trajectory

# %%
import os
import math
import numpy as np
import pandas as pd
import cv2
import imageio

SRC_ROOT = (
    "/content/drive/.shortcut-targets-by-id/"
    "1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL"
    "/NEAR_Experiment_Design/PilotData_V1_10232025"
)

# Output folder in your MyDrive
OUTPUT_DIR = "/content/drive/MyDrive/NEAR_fixation_Trajectory_Output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

INTERVAL_SEC = 3.0
GIF_FRAME_DURATION = 0.3
MIN_FIX_PER_FRAME = 1

print("Reading from (shared):", SRC_ROOT)
print("Writing outputs to:", OUTPUT_DIR)

def load_fixations(exports_dir):
    df = pd.read_csv(os.path.join(exports_dir, "fixations.csv"))
    ts_col = next((c for c in ["start_timestamp","timestamp","world_timestamp"] if c in df.columns), None)
    x_col = next((c for c in ["norm_pos_x","x","gaze_point_2d_x"] if c in df.columns), None)
    y_col = next((c for c in ["norm_pos_y","y","gaze_point_2d_y"] if c in df.columns), None)
    df = df[[ts_col, x_col, y_col]].rename(columns={ts_col:"t", x_col:"x", y_col:"y"})
    df = df.sort_values("t").reset_index(drop=True)
    return df

def load_bg(exports_dir):
    cap = cv2.VideoCapture(os.path.join(exports_dir, "world.mp4"))
    ok, frame = cap.read()
    cap.release()
    if not ok or frame is None:
        frame = np.ones((720,1280,3), dtype=np.uint8)*255
    return frame

def draw_traj(bg, df, normalize=True):
    img = bg.copy()
    h, w = img.shape[:2]
    xs = df["x"].to_numpy(float)
    ys = df["y"].to_numpy(float)
    if normalize:
        xs = np.clip(xs, 0, 1)*w
        ys = (1 - np.clip(ys, 0, 1))*h
    pts = list(zip(xs.astype(int), ys.astype(int)))
    if not pts:
        return img
    for (x1,y1),(x2,y2) in zip(pts[:-1], pts[1:]):
        cv2.line(img, (x1,y1), (x2,y2), (255,0,255), 2)
    for x,y in pts:
        cv2.circle(img, (x,y), 6, (0,255,0), -1)
    return img

# Iterate over all subjects/tasks in shared root
for subj in sorted(os.listdir(SRC_ROOT)):
    subject_dir = os.path.join(SRC_ROOT, subj)
    exports000 = os.path.join(subject_dir, "exports", "000")
    if not os.path.isdir(exports000):
        print("[SKIP-NO-DATA] ", subj)
        continue

    print("\nProcessing:", subj)
    try:
        fix_df = load_fixations(exports000)
    except Exception as e:
        print("  [ERROR load fixations]", e)
        continue

    # ADDED: Check if fix_df is empty before proceeding
    if fix_df.empty:
        print("  [SKIP] No fixations data available for", subj)
        continue

    bg = load_bg(exports000)
    normalize = ((fix_df["x"].between(0,1)).mean() > 0.5)

    t0, t1 = fix_df["t"].min(), fix_df["t"].max()
    total = t1 - t0
    n_int = int(math.ceil(total / INTERVAL_SEC))
    print(f"  Duration {total:.1f}s, {len(fix_df)} fixations → {n_int} windows")

    # static windows
    for i in range(n_int):
        ws = t0 + i*INTERVAL_SEC
        we = min(ws + INTERVAL_SEC, t1)
        dfw = fix_df[(fix_df["t"]>=ws)&(fix_df["t"]<we)]
        if dfw.empty: continue
        img = draw_traj(bg, dfw, normalize)
        label = f"{ws - t0:.1f}-{we - t0:.1f}s".replace('.', 'p')
        out_fn = f"{subj}_fixtraj_{label}.png"
        cv2.imwrite(os.path.join(OUTPUT_DIR, out_fn), img)

    # full-trajectory GIF
    frames = []
    for i in range(0, len(fix_df), MIN_FIX_PER_FRAME):
        dfp = fix_df.iloc[:i+1]
        img = draw_traj(bg, dfp, normalize)
        frames.append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    if frames:
        gif_path = os.path.join(OUTPUT_DIR, f"{subj}_fixtraj_full.gif")
        imageio.mimsave(gif_path, frames, duration=GIF_FRAME_DURATION)

    print("  → done", subj)

print("\nFinished. All outputs in:", OUTPUT_DIR)
# Out:
# Reading from (shared): /content/drive/.shortcut-targets-by-id/1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL/NEAR_Experiment_Design/PilotData_V1_10232025
# Writing outputs to: /content/drive/MyDrive/NEAR_fixation_Trajectory_Output
# [SKIP-NO-DATA]  .ipynb_checkpoints
# [SKIP-NO-DATA]  1_Data_Analysis
#
# Processing: AT_1
#   Duration 52.4s, 28 fixations → 18 windows
#   → done AT_1
#
# Processing: AT_2
#   Duration 19.1s, 10 fixations → 7 windows
#   → done AT_2
#
# Processing: AT_3_1
#   Duration 7.7s, 8 fixations → 3 windows
#   → done AT_3_1
#
# Processing: AT_3_2
#   Duration 33.6s, 23 fixations → 12 windows
#   → done AT_3_2
#
# Processing: Ayu_1
#   Duration 52.6s, 88 fixations → 18 windows
#   → done Ayu_1
#
# Processing: Ayu_2
#   Duration 31.0s, 26 fixations → 11 windows
#   → done Ayu_2
#
# Processing: Ayu_3
#   Duration 76.9s, 48 fixations → 26 windows
#   → done Ayu_3
#
# Processing: JC_1
#   Duration 49.2s, 50 fixations → 17 windows
#   → done JC_1
#
# Processing: JC_2
#   [SKIP] No fixations data available for JC_2
#
# Processing: JC_3_1
#   Duration 19.1s, 18 fixations → 7 windows
#   → done JC_3_1
#
# Processing: JC_3_2
#   Duration 37.9s, 3 fixations → 13 windows
#   → done JC_3_2
#
# Processing: KC_1
#   Duration 23.9s, 12 fixations → 8 windows
#   → done KC_1
#
# Processing: KC_2
#   Duration 37.6s, 18 fixations → 13 windows
#   → done KC_2
#
# Processing: KC_3_1
#   Duration 15.0s, 8 fixations → 6 windows
#   → done KC_3_1
#
# Processing: KC_3_2
#   Duration 15.2s, 13 fixations → 6 windows
#   → done KC_3_2
#
# Processing: LKH_1
#   Duration 19.0s, 19 fixations → 7 windows
#   → done LKH_1
#
# Processing: LKH_2
#   Duration 12.3s, 8 fixations → 5 windows
#   → done LKH_2
#
# Processing: LKH_3_1
#   Duration 1.9s, 4 fixations → 1 windows
#   → done LKH_3_1
#
# Processing: LKH_3_2
#   Duration 0.1s, 2 fixations → 1 windows
#   → done LKH_3_2
#
# Processing: SYH_1_simple
#   Duration 29.3s, 54 fixations → 10 windows
#   → done SYH_1_simple
#
# Processing: SYH_2_simple
#   Duration 14.1s, 29 fixations → 5 windows
#   → done SYH_2_simple
#
# Processing: SYH_3_1_simple
#   Duration 6.3s, 15 fixations → 3 windows
#   → done SYH_3_1_simple
#
# Processing: SYH_3_2_simple
#   Duration 12.2s, 29 fixations → 5 windows
#   → done SYH_3_2_simple
#
# Processing: YL_1
#   Duration 22.6s, 7 fixations → 8 windows
#   → done YL_1
#
# Processing: YL_2
#   Duration 25.6s, 3 fixations → 9 windows
#   → done YL_2
#
# Processing: YL_3
#   Duration 16.8s, 3 fixations → 6 windows
#   → done YL_3
#
# Finished. All outputs in: /content/drive/MyDrive/NEAR_fixation_Trajectory_Output

# %% [markdown]
# ## Blink Pupil

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import file_methods as fm
import helper_funcs as hf

# -----------------------------
# Paths & config
# -----------------------------
SRC_ROOT = (
    "/content/drive/.shortcut-targets-by-id/"
    "1BH7hdSj4Nh64k4RfY-YVSzgVZm29RTrL"
    "/NEAR_Experiment_Design/PilotData_V1_10232025"
)

SAVE_ROOT = ("/content/drive/MyDrive/NEAR_Experiment_Design/PilotData_V1_10232025/1_Data_Analysis/blink_pupil")

WINDOW_SEC = 3.0

TASK_DICT = {
    "AT":  ["AT_1", "AT_2", "AT_3_1", "AT_3_2"],
    "Ayu": ["Ayu_1", "Ayu_2", "Ayu_3"],
    "JC":  ["JC_1", "JC_2", "JC_3_1", "JC_3_2"],
    "KC":  ["KC_1", "KC_2", "KC_3_1", "KC_3_2"],
    "LKH": ["LKH_1", "LKH_2", "LKH_3_1", "LKH_3_2"],
    "SYH": ["SYH_1_simple", "SYH_2_simple", "SYH_3_1_simple", "SYH_3_2_simple"],
    "YL":  ["YL_1", "YL_2", "YL_3"],
}

# -----------------------------
# Main loop
# -----------------------------
for subject, task_list in TASK_DICT.items():

    for task in task_list:
        print(f"Processing {subject} | {task}")

        task_path = os.path.join(SRC_ROOT, task)
        save_task_dir = os.path.join(SAVE_ROOT, task)
        os.makedirs(save_task_dir, exist_ok=True)

        # ---- Load timestamps ----
        timest = np.load(os.path.join(task_path, "world_timestamps.npy"))

        # ---- Load pupil PLData ----
        cols = ['id', 'timestamp', 'topic', 'confidence',
                'norm_pos', 'diameter', 'diameter_3d']

        pupil_df = pl_to_df('pupil', task_path, cols)

        pupil_df[['norm_pos_x', 'norm_pos_y']] = pd.DataFrame(
            pupil_df['norm_pos'].tolist(), index=pupil_df.index
        )
        pupil_df.drop(columns='norm_pos', inplace=True)

        pupil_df.rename(columns={
            'confidence': 'conf',
            'diameter': 'dia_2d',
            'diameter_3d': 'dia_3d'
        }, inplace=True)

        pupil_df['seconds'] = pupil_df['timestamp'] - timest[0]
        pupil_df = pupil_df[pupil_df['topic'].str.contains('2d')]

        # ---- Windowing ----
        max_t = pupil_df['seconds'].max()
        n_windows = int(np.ceil(max_t / WINDOW_SEC))

        for w in range(n_windows):
            t_start = w * WINDOW_SEC
            t_end = t_start + WINDOW_SEC

            win_df = pupil_df[
                (pupil_df['seconds'] >= t_start) &
                (pupil_df['seconds'] < t_end)
            ]

            if win_df.empty:
                continue

            right = win_df[win_df['id'] == 0]
            left  = win_df[win_df['id'] == 1]

            # ---- Plot ----
            fig, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=True)

            axes[0].plot(right['seconds'], right['dia_2d'])
            axes[0].set_title("Eye 0", fontsize=18)
            axes[0].set_xlabel("time (s)", fontsize=18)
            axes[0].set_ylabel("diameter (mm)", fontsize=18)
            axes[0].tick_params(labelsize=16)
            axes[0].set_box_aspect(1)

            axes[1].plot(left['seconds'], left['dia_2d'])
            axes[1].set_title("Eye 1", fontsize=18)
            axes[1].set_xlabel("time (s)", fontsize=18)
            axes[1].tick_params(labelsize=16)
            axes[1].set_box_aspect(1)

            plt.tight_layout()

            # ---- Save ----
            fname = f"{task}_{t_start:.1f}-{t_end:.1f}s.png"
            plt.savefig(os.path.join(save_task_dir, fname), dpi=300)
            plt.close(fig)
# Out:
# Processing AT | AT_1
# Processing AT | AT_2
# Processing AT | AT_3_1
# Processing AT | AT_3_2
# Processing Ayu | Ayu_1
# Processing Ayu | Ayu_2
# Processing Ayu | Ayu_3
# Processing JC | JC_1
# Processing JC | JC_2
# Processing JC | JC_3_1
# Processing JC | JC_3_2
# Processing KC | KC_1
# Processing KC | KC_2
# Processing KC | KC_3_1
# Processing KC | KC_3_2
# Processing LKH | LKH_1
# Processing LKH | LKH_2
# Processing LKH | LKH_3_1
# Processing LKH | LKH_3_2
# Processing SYH | SYH_1_simple
# Processing SYH | SYH_2_simple
# Processing SYH | SYH_3_1_simple
# Processing SYH | SYH_3_2_simple
# Processing YL | YL_1
# Processing YL | YL_2
# Processing YL | YL_3
